# %%
import csv
import random
import math
import operator

def loadDataset(filename, split, trainingSet=[], testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset) - 1):
            for y in range(1, 5):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])


def euclideanDistance(instance1, instance2):
    distance = 0
    for x in range(1, 5):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)


def getNeighbors(trainingSet, testInstance, k):
    distances = []
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x])
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors


def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][0]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]

def getAccuracy(testSet, predictions):
    correct = 0

    for x in range(len(testSet)):
        if testSet[x][0] == predictions[x]:
            correct += 1
    return (correct / float(len(testSet))) * 100.0


def main():
    # prepare data
    trainingSet = []
    testSet = []
    split = 0.67
    loadDataset('balance-scale.data', split, trainingSet, testSet)
    print('Train set: ' + repr(len(trainingSet)))
    print('Test set: ' + repr(len(testSet)))
    # generate predictions
    predictions = []
    k = 1
    i = 0
    for x in range(len(testSet)):
        i += 1
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        print('t-' + str(i) +'> predicted=' + repr(result) + ', actual=' + repr(testSet[x][0]))
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')


main()
# Out:
# Train set: 422
# Test set: 202
# t-1> predicted='B', actual='R'
# t-2> predicted='R', actual='R'
# t-3> predicted='R', actual='R'
# t-4> predicted='R', actual='R'
# t-5> predicted='R', actual='R'
# t-6> predicted='R', actual='R'
# t-7> predicted='R', actual='R'
# t-8> predicted='R', actual='R'
# t-9> predicted='R', actual='R'
# t-10> predicted='R', actual='R'
# t-11> predicted='R', actual='R'
# t-12> predicted='B', actual='R'
# t-13> predicted='R', actual='R'
# t-14> predicted='R', actual='R'
# t-15> predicted='R', actual='R'
# t-16> predicted='R', actual='R'
# t-17> predicted='R', actual='R'
# t-18> predicted='R', actual='R'
# t-19> predicted='R', actual='R'
# t-20> predicted='L', actual='B'
# t-21> predicted='R', actual='R'
# t-22> predicted='R', actual='R'
# t-23> predicted='R', actual='R'
# t-24> predicted='R', actual='R'
# t-25> predicted='R', actual='R'
# t-26> predicted='L', actual='L'
# t-27> predicted='L', actual='R'
# t-28> predicted='R', actual='R'
# t-29> predicted='R', actual='B'
# t-30> predicted='R', actual='R'
# t-31> predicted='R', actual='R'
# t-32> predicted='R', actual='R'
# t-33> predicted='B', actual='L'
# t-34> predicted='R', actual='B'
# t-35> predicted='R', actual='R'
# t-36> predicted='R', actual='R'
# t-37> predicted='R', actual='R'
# t-38> predicted='R', actual='R'
# t-39> predicted='R', actual='R'
# t-40> predicted='R', actual='B'
# t-41> predicted='B', actual='L'
# t-42> predicted='R', actual='R'
# t-43> predicted='R', actual='R'
# t-44> predicted='R', actual='R'
# t-45> predicted='B', actual='R'
# t-46> predicted='R', actual='R'
# t-47> predicted='R', actual='R'
# t-48> predicted='R', actual='R'
# t-49> predicted='L', actual='L'
# t-50> predicted='L', actual='B'
# t-51> predicted='R', actual='R'
# t-52> predicted='R', actual='R'
# t-53> predicted='R', actual='R'
# t-54> predicted='R', actual='R'
# t-55> predicted='L', actual='L'
# t-56> predicted='L', actual='L'
# t-57> predicted='R', actual='L'
# t-58> predicted='L', actual='R'
# t-59> predicted='R', actual='R'
# t-60> predicted='R', actual='R'
# t-61> predicted='R', actual='R'
# t-62> predicted='R', actual='L'
# t-63> predicted='B', actual='L'
# t-64> predicted='L', actual='L'
# t-65> predicted='R', actual='R'
# t-66> predicted='R', actual='R'
# t-67> predicted='R', actual='R'
# t-68> predicted='R', actual='R'
# t-69> predicted='L', actual='L'
# t-70> predicted='L', actual='L'
# t-71> predicted='L', actual='L'
# t-72> predicted='L', actual='L'
# t-73> predicted='R', actual='L'
# t-74> predicted='R', actual='L'
# t-75> predicted='R', actual='R'
# t-76> predicted='L', actual='L'
# t-77> predicted='R', actual='R'
# t-78> predicted='R', actual='R'
# t-79> predicted='L', actual='B'
# t-80> predicted='B', actual='L'
# t-81> predicted='R', actual='R'
# t-82> predicted='R', actual='R'
# t-83> predicted='R', actual='B'
# t-84> predicted='R', actual='R'
# t-85> predicted='R', actual='R'
# t-86> predicted='L', actual='L'
# t-87> predicted='L', actual='L'
# t-88> predicted='L', actual='L'
# t-89> predicted='R', actual='B'
# t-90> predicted='R', actual='R'
# t-91> predicted='B', actual='L'
# t-92> predicted='R', actual='R'
# t-93> predicted='R', actual='R'
# t-94> predicted='L', actual='L'
# t-95> predicted='B', actual='L'
# t-96> predicted='R', actual='L'
# t-97> predicted='L', actual='L'
# t-98> predicted='R', actual='L'
# t-99> predicted='R', actual='R'
# t-100> predicted='L', actual='L'
# t-101> predicted='L', actual='L'
# t-102> predicted='B', actual='L'
# t-103> predicted='L', actual='L'
# t-104> predicted='R', actual='B'
# t-105> predicted='R', actual='R'
# t-106> predicted='R', actual='R'
# t-107> predicted='R', actual='R'
# t-108> predicted='L', actual='L'
# t-109> predicted='L', actual='L'
# t-110> predicted='L', actual='L'
# t-111> predicted='L', actual='L'
# t-112> predicted='L', actual='L'
# t-113> predicted='L', actual='L'
# t-114> predicted='L', actual='L'
# t-115> predicted='R', actual='R'
# t-116> predicted='L', actual='L'
# t-117> predicted='R', actual='R'
# t-118> predicted='R', actual='R'
# t-119> predicted='L', actual='L'
# t-120> predicted='L', actual='L'
# t-121> predicted='R', actual='R'
# t-122> predicted='R', actual='L'
# t-123> predicted='R', actual='R'
# t-124> predicted='R', actual='R'
# t-125> predicted='R', actual='R'
# t-126> predicted='R', actual='R'
# t-127> predicted='R', actual='R'
# t-128> predicted='L', actual='L'
# t-129> predicted='R', actual='B'
# t-130> predicted='L', actual='L'
# t-131> predicted='B', actual='L'
# t-132> predicted='R', actual='R'
# t-133> predicted='L', actual='L'
# t-134> predicted='L', actual='L'
# t-135> predicted='L', actual='L'
# t-136> predicted='L', actual='L'
# t-137> predicted='B', actual='L'
# t-138> predicted='B', actual='L'
# t-139> predicted='R', actual='B'
# t-140> predicted='L', actual='L'
# t-141> predicted='L', actual='L'
# t-142> predicted='L', actual='L'
# t-143> predicted='L', actual='L'
# t-144> predicted='B', actual='L'
# t-145> predicted='L', actual='L'
# t-146> predicted='B', actual='L'
# t-147> predicted='R', actual='R'
# t-148> predicted='R', actual='L'
# t-149> predicted='R', actual='R'
# t-150> predicted='R', actual='R'
# t-151> predicted='L', actual='L'
# t-152> predicted='L', actual='L'
# t-153> predicted='L', actual='L'
# t-154> predicted='B', actual='L'
# t-155> predicted='L', actual='L'
# t-156> predicted='B', actual='L'
# t-157> predicted='B', actual='R'
# t-158> predicted='L', actual='L'
# t-159> predicted='L', actual='L'
# t-160> predicted='R', actual='R'
# t-161> predicted='L', actual='L'
# t-162> predicted='R', actual='R'
# t-163> predicted='R', actual='R'
# t-164> predicted='R', actual='R'
# t-165> predicted='R', actual='R'
# t-166> predicted='R', actual='R'
# t-167> predicted='L', actual='L'
# t-168> predicted='L', actual='L'
# t-169> predicted='L', actual='L'
# t-170> predicted='R', actual='L'
# t-171> predicted='R', actual='R'
# t-172> predicted='L', actual='L'
# t-173> predicted='B', actual='L'
# t-174> predicted='R', actual='R'
# t-175> predicted='L', actual='L'
# t-176> predicted='R', actual='R'
# t-177> predicted='R', actual='R'
# t-178> predicted='L', actual='L'
# t-179> predicted='L', actual='L'
# t-180> predicted='L', actual='L'
# t-181> predicted='L', actual='L'
# t-182> predicted='B', actual='L'
# t-183> predicted='R', actual='L'
# t-184> predicted='R', actual='R'
# t-185> predicted='R', actual='R'
# t-186> predicted='R', actual='R'
# t-187> predicted='L', actual='L'
# t-188> predicted='L', actual='L'
# t-189> predicted='L', actual='L'
# t-190> predicted='L', actual='L'
# t-191> predicted='L', actual='L'
# t-192> predicted='L', actual='L'
# t-193> predicted='L', actual='L'
# t-194> predicted='L', actual='L'
# t-195> predicted='R', actual='R'
# t-196> predicted='L', actual='L'
# t-197> predicted='L', actual='L'
# t-198> predicted='L', actual='L'
# t-199> predicted='L', actual='L'
# t-200> predicted='L', actual='L'
# t-201> predicted='B', actual='L'
# t-202> predicted='L', actual='L'
# Accuracy: 78.21782178217822%

# %%
# Example of kNN implemented from Scratch in Python

import csv
import random
import math
import operator

def loadDataset(filename, split, trainingSet=[], testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset) - 1):
            for y in range(1, 5):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])


def euclideanDistance(instance1, instance2):
    distance = 0
    for x in range(1, 5):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)


def getNeighbors(trainingSet, testInstance, k):
    distances = []
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x])
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors


def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][0]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]

def getAccuracy(testSet, predictions):
    correct = 0

    for x in range(len(testSet)):
        if testSet[x][0] == predictions[x]:
            correct += 1
    return (correct / float(len(testSet))) * 100.0


def main():
    # prepare data
    trainingSet = []
    testSet = []
    split = 0.67
    loadDataset('balance-scale.data', split, trainingSet, testSet)
    print('Train set: ' + repr(len(trainingSet)))
    print('Test set: ' + repr(len(testSet)))
    # generate predictions
    predictions = []
    k = 2
    i = 0
    for x in range(len(testSet)):
        i += 1
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        print('t-' + str(i) +'> predicted=' + repr(result) + ', actual=' + repr(testSet[x][0]))
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')


main()
# Out:
# Train set: 415
# Test set: 209
# t-1> predicted='B', actual='R'
# t-2> predicted='R', actual='R'
# t-3> predicted='R', actual='R'
# t-4> predicted='R', actual='R'
# t-5> predicted='B', actual='L'
# t-6> predicted='R', actual='B'
# t-7> predicted='R', actual='R'
# t-8> predicted='R', actual='R'
# t-9> predicted='R', actual='R'
# t-10> predicted='R', actual='R'
# t-11> predicted='R', actual='R'
# t-12> predicted='R', actual='R'
# t-13> predicted='L', actual='L'
# t-14> predicted='R', actual='R'
# t-15> predicted='R', actual='R'
# t-16> predicted='R', actual='R'
# t-17> predicted='R', actual='R'
# t-18> predicted='R', actual='R'
# t-19> predicted='R', actual='R'
# t-20> predicted='B', actual='L'
# t-21> predicted='R', actual='B'
# t-22> predicted='R', actual='R'
# t-23> predicted='R', actual='R'
# t-24> predicted='R', actual='R'
# t-25> predicted='B', actual='R'
# t-26> predicted='R', actual='R'
# t-27> predicted='L', actual='L'
# t-28> predicted='L', actual='L'
# t-29> predicted='R', actual='R'
# t-30> predicted='L', actual='L'
# t-31> predicted='B', actual='L'
# t-32> predicted='R', actual='R'
# t-33> predicted='R', actual='R'
# t-34> predicted='L', actual='B'
# t-35> predicted='R', actual='R'
# t-36> predicted='R', actual='R'
# t-37> predicted='R', actual='R'
# t-38> predicted='R', actual='R'
# t-39> predicted='R', actual='R'
# t-40> predicted='R', actual='R'
# t-41> predicted='R', actual='R'
# t-42> predicted='R', actual='R'
# t-43> predicted='R', actual='R'
# t-44> predicted='R', actual='R'
# t-45> predicted='L', actual='L'
# t-46> predicted='R', actual='B'
# t-47> predicted='R', actual='R'
# t-48> predicted='L', actual='L'
# t-49> predicted='R', actual='R'
# t-50> predicted='R', actual='B'
# t-51> predicted='R', actual='R'
# t-52> predicted='R', actual='R'
# t-53> predicted='R', actual='R'
# t-54> predicted='R', actual='R'
# t-55> predicted='R', actual='R'
# t-56> predicted='B', actual='L'
# t-57> predicted='L', actual='L'
# t-58> predicted='R', actual='L'
# t-59> predicted='R', actual='R'
# t-60> predicted='R', actual='R'
# t-61> predicted='R', actual='R'
# t-62> predicted='R', actual='R'
# t-63> predicted='R', actual='R'
# t-64> predicted='L', actual='L'
# t-65> predicted='R', actual='R'
# t-66> predicted='R', actual='R'
# t-67> predicted='R', actual='R'
# t-68> predicted='L', actual='L'
# t-69> predicted='L', actual='L'
# t-70> predicted='L', actual='L'
# t-71> predicted='R', actual='L'
# t-72> predicted='R', actual='L'
# t-73> predicted='R', actual='L'
# t-74> predicted='R', actual='L'
# t-75> predicted='R', actual='R'
# t-76> predicted='R', actual='R'
# t-77> predicted='R', actual='R'
# t-78> predicted='R', actual='R'
# t-79> predicted='R', actual='R'
# t-80> predicted='R', actual='R'
# t-81> predicted='R', actual='R'
# t-82> predicted='R', actual='R'
# t-83> predicted='R', actual='R'
# t-84> predicted='R', actual='R'
# t-85> predicted='R', actual='R'
# t-86> predicted='R', actual='R'
# t-87> predicted='L', actual='L'
# t-88> predicted='L', actual='L'
# t-89> predicted='R', actual='L'
# t-90> predicted='L', actual='L'
# t-91> predicted='R', actual='B'
# t-92> predicted='R', actual='R'
# t-93> predicted='R', actual='R'
# t-94> predicted='R', actual='R'
# t-95> predicted='R', actual='R'
# t-96> predicted='R', actual='R'
# t-97> predicted='L', actual='L'
# t-98> predicted='L', actual='L'
# t-99> predicted='L', actual='L'
# t-100> predicted='L', actual='L'
# t-101> predicted='L', actual='L'
# t-102> predicted='R', actual='L'
# t-103> predicted='L', actual='L'
# t-104> predicted='L', actual='L'
# t-105> predicted='R', actual='R'
# t-106> predicted='R', actual='R'
# t-107> predicted='R', actual='R'
# t-108> predicted='L', actual='L'
# t-109> predicted='L', actual='L'
# t-110> predicted='L', actual='L'
# t-111> predicted='L', actual='L'
# t-112> predicted='L', actual='L'
# t-113> predicted='B', actual='L'
# t-114> predicted='R', actual='L'
# t-115> predicted='L', actual='L'
# t-116> predicted='R', actual='R'
# t-117> predicted='L', actual='L'
# t-118> predicted='L', actual='L'
# t-119> predicted='L', actual='L'
# t-120> predicted='R', actual='B'
# t-121> predicted='L', actual='L'
# t-122> predicted='R', actual='R'
# t-123> predicted='R', actual='R'
# t-124> predicted='R', actual='R'
# t-125> predicted='R', actual='R'
# t-126> predicted='R', actual='R'
# t-127> predicted='L', actual='L'
# t-128> predicted='L', actual='L'
# t-129> predicted='R', actual='B'
# t-130> predicted='L', actual='L'
# t-131> predicted='R', actual='R'
# t-132> predicted='R', actual='B'
# t-133> predicted='R', actual='R'
# t-134> predicted='R', actual='R'
# t-135> predicted='L', actual='L'
# t-136> predicted='L', actual='L'
# t-137> predicted='R', actual='R'
# t-138> predicted='R', actual='R'
# t-139> predicted='R', actual='R'
# t-140> predicted='L', actual='L'
# t-141> predicted='L', actual='L'
# t-142> predicted='L', actual='L'
# t-143> predicted='L', actual='L'
# t-144> predicted='L', actual='L'
# t-145> predicted='L', actual='L'
# t-146> predicted='B', actual='L'
# t-147> predicted='R', actual='B'
# t-148> predicted='R', actual='R'
# t-149> predicted='R', actual='R'
# t-150> predicted='L', actual='L'
# t-151> predicted='L', actual='L'
# t-152> predicted='L', actual='L'
# t-153> predicted='L', actual='L'
# t-154> predicted='L', actual='L'
# t-155> predicted='L', actual='L'
# t-156> predicted='L', actual='L'
# t-157> predicted='L', actual='L'
# t-158> predicted='L', actual='L'
# t-159> predicted='B', actual='L'
# t-160> predicted='B', actual='R'
# t-161> predicted='L', actual='L'
# t-162> predicted='B', actual='L'
# t-163> predicted='L', actual='L'
# t-164> predicted='R', actual='R'
# t-165> predicted='L', actual='L'
# t-166> predicted='R', actual='R'
# t-167> predicted='B', actual='L'
# t-168> predicted='R', actual='R'
# t-169> predicted='R', actual='R'
# t-170> predicted='L', actual='L'
# t-171> predicted='L', actual='L'
# t-172> predicted='L', actual='L'
# t-173> predicted='L', actual='L'
# t-174> predicted='L', actual='L'
# t-175> predicted='R', actual='R'
# t-176> predicted='R', actual='R'
# t-177> predicted='R', actual='R'
# t-178> predicted='L', actual='L'
# t-179> predicted='L', actual='L'
# t-180> predicted='L', actual='L'
# t-181> predicted='L', actual='L'
# t-182> predicted='L', actual='L'
# t-183> predicted='L', actual='L'
# t-184> predicted='L', actual='L'
# t-185> predicted='B', actual='L'
# t-186> predicted='R', actual='B'
# t-187> predicted='L', actual='L'
# t-188> predicted='L', actual='L'
# t-189> predicted='L', actual='R'
# t-190> predicted='R', actual='R'
# t-191> predicted='L', actual='L'
# t-192> predicted='R', actual='R'
# t-193> predicted='L', actual='L'
# t-194> predicted='L', actual='L'
# t-195> predicted='L', actual='L'
# t-196> predicted='L', actual='L'
# t-197> predicted='L', actual='L'
# t-198> predicted='L', actual='L'
# t-199> predicted='L', actual='L'
# t-200> predicted='R', actual='B'
# t-201> predicted='L', actual='L'
# t-202> predicted='L', actual='L'
# t-203> predicted='L', actual='L'
# t-204> predicted='L', actual='L'
# t-205> predicted='L', actual='L'
# t-206> predicted='L', actual='L'
# t-207> predicted='L', actual='L'
# t-208> predicted='L', actual='L'
# t-209> predicted='L', actual='L'
# Accuracy: 83.73205741626795%

# %%
# Example of kNN implemented from Scratch in Python

import csv
import random
import math
import operator

def loadDataset(filename, split, trainingSet=[], testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset) - 1):
            for y in range(1, 5):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])


def euclideanDistance(instance1, instance2):
    distance = 0
    for x in range(1, 5):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)


def getNeighbors(trainingSet, testInstance, k):
    distances = []
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x])
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors


def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][0]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]

def getAccuracy(testSet, predictions):
    correct = 0

    for x in range(len(testSet)):
        if testSet[x][0] == predictions[x]:
            correct += 1
    return (correct / float(len(testSet))) * 100.0


def main():
    # prepare data
    trainingSet = []
    testSet = []
    split = 0.67
    loadDataset('balance-scale.data', split, trainingSet, testSet)
    print('Train set: ' + repr(len(trainingSet)))
    print('Test set: ' + repr(len(testSet)))
    # generate predictions
    predictions = []
    k = 3
    i = 0
    for x in range(len(testSet)):
        i += 1
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        print('t-' + str(i) +'> predicted=' + repr(result) + ', actual=' + repr(testSet[x][0]))
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')


main()
# Out:
# Train set: 443
# Test set: 181
# t-1> predicted='R', actual='R'
# t-2> predicted='R', actual='R'
# t-3> predicted='R', actual='R'
# t-4> predicted='R', actual='R'
# t-5> predicted='R', actual='B'
# t-6> predicted='R', actual='R'
# t-7> predicted='R', actual='R'
# t-8> predicted='R', actual='R'
# t-9> predicted='R', actual='R'
# t-10> predicted='R', actual='R'
# t-11> predicted='R', actual='R'
# t-12> predicted='R', actual='R'
# t-13> predicted='R', actual='R'
# t-14> predicted='L', actual='L'
# t-15> predicted='L', actual='L'
# t-16> predicted='B', actual='L'
# t-17> predicted='R', actual='R'
# t-18> predicted='R', actual='B'
# t-19> predicted='R', actual='R'
# t-20> predicted='R', actual='R'
# t-21> predicted='R', actual='R'
# t-22> predicted='R', actual='R'
# t-23> predicted='L', actual='L'
# t-24> predicted='L', actual='L'
# t-25> predicted='R', actual='B'
# t-26> predicted='L', actual='L'
# t-27> predicted='B', actual='L'
# t-28> predicted='R', actual='R'
# t-29> predicted='R', actual='R'
# t-30> predicted='R', actual='R'
# t-31> predicted='R', actual='R'
# t-32> predicted='R', actual='R'
# t-33> predicted='R', actual='R'
# t-34> predicted='R', actual='R'
# t-35> predicted='R', actual='R'
# t-36> predicted='B', actual='R'
# t-37> predicted='R', actual='R'
# t-38> predicted='R', actual='R'
# t-39> predicted='R', actual='R'
# t-40> predicted='R', actual='R'
# t-41> predicted='L', actual='L'
# t-42> predicted='B', actual='L'
# t-43> predicted='R', actual='L'
# t-44> predicted='R', actual='R'
# t-45> predicted='R', actual='R'
# t-46> predicted='R', actual='R'
# t-47> predicted='R', actual='R'
# t-48> predicted='R', actual='R'
# t-49> predicted='R', actual='R'
# t-50> predicted='R', actual='L'
# t-51> predicted='L', actual='B'
# t-52> predicted='R', actual='R'
# t-53> predicted='L', actual='B'
# t-54> predicted='R', actual='R'
# t-55> predicted='R', actual='R'
# t-56> predicted='R', actual='R'
# t-57> predicted='L', actual='L'
# t-58> predicted='L', actual='L'
# t-59> predicted='R', actual='L'
# t-60> predicted='R', actual='B'
# t-61> predicted='L', actual='L'
# t-62> predicted='R', actual='R'
# t-63> predicted='R', actual='R'
# t-64> predicted='L', actual='L'
# t-65> predicted='B', actual='L'
# t-66> predicted='L', actual='L'
# t-67> predicted='L', actual='L'
# t-68> predicted='L', actual='R'
# t-69> predicted='R', actual='R'
# t-70> predicted='L', actual='L'
# t-71> predicted='R', actual='R'
# t-72> predicted='R', actual='R'
# t-73> predicted='L', actual='L'
# t-74> predicted='R', actual='R'
# t-75> predicted='R', actual='R'
# t-76> predicted='R', actual='R'
# t-77> predicted='R', actual='R'
# t-78> predicted='R', actual='R'
# t-79> predicted='R', actual='L'
# t-80> predicted='L', actual='B'
# t-81> predicted='L', actual='B'
# t-82> predicted='L', actual='L'
# t-83> predicted='L', actual='L'
# t-84> predicted='L', actual='L'
# t-85> predicted='L', actual='L'
# t-86> predicted='L', actual='R'
# t-87> predicted='L', actual='L'
# t-88> predicted='R', actual='L'
# t-89> predicted='R', actual='R'
# t-90> predicted='L', actual='L'
# t-91> predicted='L', actual='L'
# t-92> predicted='L', actual='L'
# t-93> predicted='R', actual='L'
# t-94> predicted='L', actual='L'
# t-95> predicted='L', actual='L'
# t-96> predicted='R', actual='R'
# t-97> predicted='L', actual='L'
# t-98> predicted='L', actual='L'
# t-99> predicted='R', actual='R'
# t-100> predicted='R', actual='R'
# t-101> predicted='L', actual='L'
# t-102> predicted='L', actual='L'
# t-103> predicted='L', actual='L'
# t-104> predicted='L', actual='L'
# t-105> predicted='L', actual='B'
# t-106> predicted='L', actual='L'
# t-107> predicted='R', actual='L'
# t-108> predicted='L', actual='L'
# t-109> predicted='L', actual='B'
# t-110> predicted='R', actual='R'
# t-111> predicted='B', actual='L'
# t-112> predicted='R', actual='B'
# t-113> predicted='R', actual='R'
# t-114> predicted='R', actual='R'
# t-115> predicted='R', actual='R'
# t-116> predicted='L', actual='L'
# t-117> predicted='L', actual='L'
# t-118> predicted='R', actual='L'
# t-119> predicted='L', actual='L'
# t-120> predicted='L', actual='B'
# t-121> predicted='L', actual='L'
# t-122> predicted='L', actual='L'
# t-123> predicted='L', actual='L'
# t-124> predicted='L', actual='L'
# t-125> predicted='L', actual='L'
# t-126> predicted='R', actual='L'
# t-127> predicted='R', actual='R'
# t-128> predicted='L', actual='L'
# t-129> predicted='L', actual='L'
# t-130> predicted='L', actual='L'
# t-131> predicted='L', actual='L'
# t-132> predicted='L', actual='L'
# t-133> predicted='L', actual='L'
# t-134> predicted='L', actual='L'
# t-135> predicted='B', actual='L'
# t-136> predicted='L', actual='L'
# t-137> predicted='L', actual='L'
# t-138> predicted='L', actual='L'
# t-139> predicted='L', actual='L'
# t-140> predicted='L', actual='L'
# t-141> predicted='R', actual='B'
# t-142> predicted='L', actual='L'
# t-143> predicted='R', actual='B'
# t-144> predicted='L', actual='L'
# t-145> predicted='B', actual='L'
# t-146> predicted='R', actual='R'
# t-147> predicted='L', actual='L'
# t-148> predicted='R', actual='R'
# t-149> predicted='R', actual='R'
# t-150> predicted='R', actual='R'
# t-151> predicted='L', actual='L'
# t-152> predicted='L', actual='L'
# t-153> predicted='L', actual='L'
# t-154> predicted='L', actual='L'
# t-155> predicted='R', actual='B'
# t-156> predicted='L', actual='L'
# t-157> predicted='R', actual='R'
# t-158> predicted='L', actual='L'
# t-159> predicted='L', actual='L'
# t-160> predicted='L', actual='L'
# t-161> predicted='L', actual='L'
# t-162> predicted='R', actual='B'
# t-163> predicted='L', actual='L'
# t-164> predicted='L', actual='L'
# t-165> predicted='B', actual='L'
# t-166> predicted='R', actual='R'
# t-167> predicted='L', actual='L'
# t-168> predicted='R', actual='R'
# t-169> predicted='L', actual='L'
# t-170> predicted='L', actual='L'
# t-171> predicted='L', actual='L'
# t-172> predicted='L', actual='L'
# t-173> predicted='L', actual='L'
# t-174> predicted='L', actual='L'
# t-175> predicted='R', actual='R'
# t-176> predicted='L', actual='L'
# t-177> predicted='L', actual='L'
# t-178> predicted='L', actual='L'
# t-179> predicted='L', actual='L'
# t-180> predicted='L', actual='L'
# t-181> predicted='L', actual='L'
# Accuracy: 80.11049723756905%

# %%
# Example of kNN implemented from Scratch in Python

import csv
import random
import math
import operator

def loadDataset(filename, split, trainingSet=[], testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset) - 1):
            for y in range(1, 5):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])


def euclideanDistance(instance1, instance2):
    distance = 0
    for x in range(1, 5):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)


def getNeighbors(trainingSet, testInstance, k):
    distances = []
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x])
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors


def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][0]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]

def getAccuracy(testSet, predictions):
    correct = 0

    for x in range(len(testSet)):
        if testSet[x][0] == predictions[x]:
            correct += 1
    return (correct / float(len(testSet))) * 100.0


def main():
    # prepare data
    trainingSet = []
    testSet = []
    split = 0.67
    loadDataset('balance-scale.data', split, trainingSet, testSet)
    print('Train set: ' + repr(len(trainingSet)))
    print('Test set: ' + repr(len(testSet)))
    # generate predictions
    predictions = []
    k = 4
    i = 0
    for x in range(len(testSet)):
        i += 1
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        print('t-' + str(i) +'> predicted=' + repr(result) + ', actual=' + repr(testSet[x][0]))
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')


main()
# Out:
# Train set: 429
# Test set: 195
# t-1> predicted='R', actual='R'
# t-2> predicted='B', actual='R'
# t-3> predicted='R', actual='R'
# t-4> predicted='R', actual='R'
# t-5> predicted='R', actual='R'
# t-6> predicted='R', actual='R'
# t-7> predicted='R', actual='R'
# t-8> predicted='R', actual='R'
# t-9> predicted='R', actual='R'
# t-10> predicted='R', actual='R'
# t-11> predicted='R', actual='R'
# t-12> predicted='L', actual='L'
# t-13> predicted='R', actual='B'
# t-14> predicted='R', actual='R'
# t-15> predicted='L', actual='R'
# t-16> predicted='R', actual='R'
# t-17> predicted='R', actual='R'
# t-18> predicted='R', actual='R'
# t-19> predicted='R', actual='R'
# t-20> predicted='R', actual='R'
# t-21> predicted='R', actual='R'
# t-22> predicted='R', actual='R'
# t-23> predicted='L', actual='L'
# t-24> predicted='R', actual='R'
# t-25> predicted='R', actual='R'
# t-26> predicted='L', actual='B'
# t-27> predicted='R', actual='R'
# t-28> predicted='R', actual='R'
# t-29> predicted='R', actual='R'
# t-30> predicted='B', actual='L'
# t-31> predicted='L', actual='L'
# t-32> predicted='R', actual='R'
# t-33> predicted='L', actual='L'
# t-34> predicted='R', actual='R'
# t-35> predicted='R', actual='B'
# t-36> predicted='R', actual='R'
# t-37> predicted='L', actual='B'
# t-38> predicted='R', actual='R'
# t-39> predicted='R', actual='R'
# t-40> predicted='R', actual='R'
# t-41> predicted='R', actual='R'
# t-42> predicted='R', actual='R'
# t-43> predicted='R', actual='R'
# t-44> predicted='R', actual='R'
# t-45> predicted='R', actual='R'
# t-46> predicted='L', actual='L'
# t-47> predicted='R', actual='R'
# t-48> predicted='R', actual='B'
# t-49> predicted='R', actual='R'
# t-50> predicted='R', actual='R'
# t-51> predicted='R', actual='R'
# t-52> predicted='R', actual='R'
# t-53> predicted='L', actual='L'
# t-54> predicted='L', actual='L'
# t-55> predicted='R', actual='R'
# t-56> predicted='R', actual='R'
# t-57> predicted='B', actual='L'
# t-58> predicted='R', actual='R'
# t-59> predicted='R', actual='R'
# t-60> predicted='R', actual='R'
# t-61> predicted='L', actual='L'
# t-62> predicted='L', actual='L'
# t-63> predicted='R', actual='R'
# t-64> predicted='L', actual='L'
# t-65> predicted='R', actual='R'
# t-66> predicted='L', actual='L'
# t-67> predicted='L', actual='L'
# t-68> predicted='L', actual='L'
# t-69> predicted='B', actual='L'
# t-70> predicted='R', actual='L'
# t-71> predicted='R', actual='R'
# t-72> predicted='R', actual='R'
# t-73> predicted='R', actual='R'
# t-74> predicted='R', actual='B'
# t-75> predicted='R', actual='B'
# t-76> predicted='R', actual='R'
# t-77> predicted='R', actual='R'
# t-78> predicted='R', actual='R'
# t-79> predicted='R', actual='R'
# t-80> predicted='R', actual='R'
# t-81> predicted='L', actual='L'
# t-82> predicted='R', actual='L'
# t-83> predicted='L', actual='L'
# t-84> predicted='B', actual='L'
# t-85> predicted='R', actual='B'
# t-86> predicted='R', actual='R'
# t-87> predicted='R', actual='R'
# t-88> predicted='R', actual='R'
# t-89> predicted='R', actual='R'
# t-90> predicted='R', actual='R'
# t-91> predicted='R', actual='R'
# t-92> predicted='L', actual='L'
# t-93> predicted='L', actual='L'
# t-94> predicted='L', actual='R'
# t-95> predicted='R', actual='R'
# t-96> predicted='L', actual='L'
# t-97> predicted='R', actual='R'
# t-98> predicted='L', actual='L'
# t-99> predicted='R', actual='R'
# t-100> predicted='L', actual='L'
# t-101> predicted='L', actual='L'
# t-102> predicted='L', actual='L'
# t-103> predicted='L', actual='L'
# t-104> predicted='R', actual='B'
# t-105> predicted='R', actual='R'
# t-106> predicted='R', actual='L'
# t-107> predicted='R', actual='R'
# t-108> predicted='L', actual='L'
# t-109> predicted='L', actual='L'
# t-110> predicted='L', actual='L'
# t-111> predicted='L', actual='L'
# t-112> predicted='L', actual='L'
# t-113> predicted='L', actual='L'
# t-114> predicted='L', actual='L'
# t-115> predicted='L', actual='L'
# t-116> predicted='B', actual='L'
# t-117> predicted='L', actual='L'
# t-118> predicted='L', actual='L'
# t-119> predicted='R', actual='R'
# t-120> predicted='R', actual='R'
# t-121> predicted='L', actual='L'
# t-122> predicted='R', actual='R'
# t-123> predicted='R', actual='R'
# t-124> predicted='B', actual='R'
# t-125> predicted='R', actual='R'
# t-126> predicted='R', actual='R'
# t-127> predicted='R', actual='R'
# t-128> predicted='L', actual='L'
# t-129> predicted='L', actual='L'
# t-130> predicted='L', actual='L'
# t-131> predicted='R', actual='B'
# t-132> predicted='R', actual='R'
# t-133> predicted='R', actual='R'
# t-134> predicted='R', actual='R'
# t-135> predicted='R', actual='R'
# t-136> predicted='R', actual='R'
# t-137> predicted='L', actual='L'
# t-138> predicted='L', actual='L'
# t-139> predicted='L', actual='L'
# t-140> predicted='L', actual='L'
# t-141> predicted='B', actual='R'
# t-142> predicted='L', actual='L'
# t-143> predicted='B', actual='L'
# t-144> predicted='B', actual='R'
# t-145> predicted='R', actual='R'
# t-146> predicted='L', actual='L'
# t-147> predicted='L', actual='L'
# t-148> predicted='L', actual='L'
# t-149> predicted='R', actual='B'
# t-150> predicted='B', actual='R'
# t-151> predicted='L', actual='L'
# t-152> predicted='L', actual='L'
# t-153> predicted='R', actual='R'
# t-154> predicted='L', actual='L'
# t-155> predicted='L', actual='L'
# t-156> predicted='L', actual='L'
# t-157> predicted='L', actual='L'
# t-158> predicted='L', actual='L'
# t-159> predicted='L', actual='L'
# t-160> predicted='L', actual='L'
# t-161> predicted='L', actual='L'
# t-162> predicted='R', actual='B'
# t-163> predicted='L', actual='L'
# t-164> predicted='L', actual='L'
# t-165> predicted='R', actual='B'
# t-166> predicted='L', actual='L'
# t-167> predicted='R', actual='R'
# t-168> predicted='R', actual='R'
# t-169> predicted='B', actual='L'
# t-170> predicted='R', actual='R'
# t-171> predicted='R', actual='R'
# t-172> predicted='R', actual='R'
# t-173> predicted='L', actual='L'
# t-174> predicted='L', actual='L'
# t-175> predicted='L', actual='L'
# t-176> predicted='L', actual='L'
# t-177> predicted='R', actual='B'
# t-178> predicted='L', actual='L'
# t-179> predicted='R', actual='L'
# t-180> predicted='R', actual='R'
# t-181> predicted='R', actual='R'
# t-182> predicted='L', actual='L'
# t-183> predicted='L', actual='L'
# t-184> predicted='L', actual='L'
# t-185> predicted='L', actual='L'
# t-186> predicted='R', actual='B'
# t-187> predicted='L', actual='L'
# t-188> predicted='L', actual='L'
# t-189> predicted='L', actual='L'
# t-190> predicted='L', actual='L'
# t-191> predicted='R', actual='B'
# t-192> predicted='L', actual='L'
# t-193> predicted='L', actual='L'
# t-194> predicted='L', actual='L'
# t-195> predicted='L', actual='L'
# Accuracy: 82.56410256410255%

# %%
# Example of kNN implemented from Scratch in Python

import csv
import random
import math
import operator

def loadDataset(filename, split, trainingSet=[], testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset) - 1):
            for y in range(1, 5):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])


def euclideanDistance(instance1, instance2):
    distance = 0
    for x in range(1, 5):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)


def getNeighbors(trainingSet, testInstance, k):
    distances = []
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x])
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors


def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][0]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]

def getAccuracy(testSet, predictions):
    correct = 0

    for x in range(len(testSet)):
        if testSet[x][0] == predictions[x]:
            correct += 1
    return (correct / float(len(testSet))) * 100.0


def main():
    # prepare data
    trainingSet = []
    testSet = []
    split = 0.67
    loadDataset('balance-scale.data', split, trainingSet, testSet)
    print('Train set: ' + repr(len(trainingSet)))
    print('Test set: ' + repr(len(testSet)))
    # generate predictions
    predictions = []
    k = 5
    i = 0
    for x in range(len(testSet)):
        i += 1
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        print('t-' + str(i) +'> predicted=' + repr(result) + ', actual=' + repr(testSet[x][0]))
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')


main()
# Out:
# Train set: 438
# Test set: 186
# t-1> predicted='R', actual='B'
# t-2> predicted='R', actual='R'
# t-3> predicted='R', actual='R'
# t-4> predicted='R', actual='R'
# t-5> predicted='R', actual='R'
# t-6> predicted='R', actual='R'
# t-7> predicted='R', actual='R'
# t-8> predicted='R', actual='R'
# t-9> predicted='R', actual='R'
# t-10> predicted='R', actual='R'
# t-11> predicted='R', actual='R'
# t-12> predicted='R', actual='R'
# t-13> predicted='R', actual='R'
# t-14> predicted='R', actual='R'
# t-15> predicted='R', actual='R'
# t-16> predicted='R', actual='R'
# t-17> predicted='B', actual='L'
# t-18> predicted='R', actual='R'
# t-19> predicted='B', actual='L'
# t-20> predicted='R', actual='R'
# t-21> predicted='R', actual='R'
# t-22> predicted='R', actual='R'
# t-23> predicted='R', actual='R'
# t-24> predicted='R', actual='R'
# t-25> predicted='R', actual='R'
# t-26> predicted='R', actual='R'
# t-27> predicted='R', actual='R'
# t-28> predicted='L', actual='L'
# t-29> predicted='R', actual='R'
# t-30> predicted='R', actual='R'
# t-31> predicted='R', actual='R'
# t-32> predicted='R', actual='R'
# t-33> predicted='R', actual='R'
# t-34> predicted='B', actual='L'
# t-35> predicted='L', actual='R'
# t-36> predicted='R', actual='R'
# t-37> predicted='R', actual='R'
# t-38> predicted='R', actual='R'
# t-39> predicted='R', actual='R'
# t-40> predicted='R', actual='R'
# t-41> predicted='R', actual='R'
# t-42> predicted='R', actual='R'
# t-43> predicted='R', actual='B'
# t-44> predicted='R', actual='R'
# t-45> predicted='B', actual='L'
# t-46> predicted='R', actual='R'
# t-47> predicted='R', actual='R'
# t-48> predicted='R', actual='R'
# t-49> predicted='L', actual='L'
# t-50> predicted='L', actual='L'
# t-51> predicted='R', actual='R'
# t-52> predicted='R', actual='L'
# t-53> predicted='R', actual='R'
# t-54> predicted='L', actual='L'
# t-55> predicted='L', actual='L'
# t-56> predicted='L', actual='B'
# t-57> predicted='R', actual='R'
# t-58> predicted='L', actual='L'
# t-59> predicted='R', actual='R'
# t-60> predicted='R', actual='R'
# t-61> predicted='L', actual='L'
# t-62> predicted='L', actual='L'
# t-63> predicted='L', actual='L'
# t-64> predicted='R', actual='R'
# t-65> predicted='R', actual='R'
# t-66> predicted='R', actual='R'
# t-67> predicted='L', actual='L'
# t-68> predicted='R', actual='R'
# t-69> predicted='R', actual='R'
# t-70> predicted='R', actual='B'
# t-71> predicted='R', actual='R'
# t-72> predicted='R', actual='R'
# t-73> predicted='L', actual='L'
# t-74> predicted='L', actual='L'
# t-75> predicted='R', actual='B'
# t-76> predicted='R', actual='R'
# t-77> predicted='R', actual='R'
# t-78> predicted='L', actual='L'
# t-79> predicted='L', actual='L'
# t-80> predicted='L', actual='L'
# t-81> predicted='L', actual='L'
# t-82> predicted='L', actual='L'
# t-83> predicted='L', actual='L'
# t-84> predicted='R', actual='B'
# t-85> predicted='R', actual='R'
# t-86> predicted='L', actual='L'
# t-87> predicted='L', actual='R'
# t-88> predicted='R', actual='R'
# t-89> predicted='R', actual='R'
# t-90> predicted='L', actual='L'
# t-91> predicted='L', actual='L'
# t-92> predicted='L', actual='L'
# t-93> predicted='L', actual='L'
# t-94> predicted='R', actual='R'
# t-95> predicted='L', actual='L'
# t-96> predicted='R', actual='R'
# t-97> predicted='L', actual='L'
# t-98> predicted='L', actual='L'
# t-99> predicted='L', actual='L'
# t-100> predicted='L', actual='L'
# t-101> predicted='L', actual='L'
# t-102> predicted='R', actual='B'
# t-103> predicted='R', actual='L'
# t-104> predicted='L', actual='L'
# t-105> predicted='R', actual='R'
# t-106> predicted='R', actual='R'
# t-107> predicted='R', actual='R'
# t-108> predicted='R', actual='R'
# t-109> predicted='R', actual='R'
# t-110> predicted='R', actual='R'
# t-111> predicted='L', actual='L'
# t-112> predicted='L', actual='L'
# t-113> predicted='L', actual='L'
# t-114> predicted='R', actual='B'
# t-115> predicted='R', actual='R'
# t-116> predicted='R', actual='R'
# t-117> predicted='R', actual='R'
# t-118> predicted='L', actual='L'
# t-119> predicted='L', actual='L'
# t-120> predicted='L', actual='L'
# t-121> predicted='R', actual='L'
# t-122> predicted='L', actual='L'
# t-123> predicted='L', actual='B'
# t-124> predicted='R', actual='R'
# t-125> predicted='L', actual='L'
# t-126> predicted='L', actual='L'
# t-127> predicted='L', actual='L'
# t-128> predicted='L', actual='L'
# t-129> predicted='L', actual='L'
# t-130> predicted='L', actual='L'
# t-131> predicted='R', actual='B'
# t-132> predicted='R', actual='R'
# t-133> predicted='L', actual='L'
# t-134> predicted='L', actual='L'
# t-135> predicted='L', actual='L'
# t-136> predicted='L', actual='L'
# t-137> predicted='L', actual='L'
# t-138> predicted='R', actual='R'
# t-139> predicted='R', actual='R'
# t-140> predicted='R', actual='R'
# t-141> predicted='L', actual='L'
# t-142> predicted='R', actual='R'
# t-143> predicted='R', actual='R'
# t-144> predicted='R', actual='R'
# t-145> predicted='L', actual='L'
# t-146> predicted='L', actual='L'
# t-147> predicted='L', actual='L'
# t-148> predicted='L', actual='L'
# t-149> predicted='L', actual='L'
# t-150> predicted='L', actual='L'
# t-151> predicted='L', actual='L'
# t-152> predicted='R', actual='R'
# t-153> predicted='R', actual='R'
# t-154> predicted='L', actual='L'
# t-155> predicted='R', actual='R'
# t-156> predicted='R', actual='R'
# t-157> predicted='R', actual='R'
# t-158> predicted='R', actual='R'
# t-159> predicted='L', actual='L'
# t-160> predicted='L', actual='L'
# t-161> predicted='L', actual='L'
# t-162> predicted='L', actual='L'
# t-163> predicted='L', actual='L'
# t-164> predicted='L', actual='L'
# t-165> predicted='L', actual='L'
# t-166> predicted='B', actual='L'
# t-167> predicted='L', actual='L'
# t-168> predicted='L', actual='L'
# t-169> predicted='R', actual='R'
# t-170> predicted='L', actual='L'
# t-171> predicted='L', actual='L'
# t-172> predicted='L', actual='L'
# t-173> predicted='L', actual='L'
# t-174> predicted='L', actual='L'
# t-175> predicted='L', actual='L'
# t-176> predicted='L', actual='L'
# t-177> predicted='L', actual='L'
# t-178> predicted='L', actual='L'
# t-179> predicted='L', actual='L'
# t-180> predicted='L', actual='L'
# t-181> predicted='L', actual='L'
# t-182> predicted='L', actual='L'
# t-183> predicted='L', actual='L'
# t-184> predicted='L', actual='L'
# t-185> predicted='L', actual='L'
# t-186> predicted='B', actual='L'
# Accuracy: 88.70967741935483%

# %%
# Example of kNN implemented from Scratch in Python

import csv
import random
import math
import operator

def loadDataset(filename, split, trainingSet=[], testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset) - 1):
            for y in range(1, 5):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])


def euclideanDistance(instance1, instance2):
    distance = 0
    for x in range(1, 5):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)


def getNeighbors(trainingSet, testInstance, k):
    distances = []
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x])
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors


def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][0]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]

def getAccuracy(testSet, predictions):
    correct = 0

    for x in range(len(testSet)):
        if testSet[x][0] == predictions[x]:
            correct += 1
    return (correct / float(len(testSet))) * 100.0


def main():
    # prepare data
    trainingSet = []
    testSet = []
    split = 0.67
    loadDataset('balance-scale.data', split, trainingSet, testSet)
    print('Train set: ' + repr(len(trainingSet)))
    print('Test set: ' + repr(len(testSet)))
    # generate predictions
    predictions = []
    k = 6
    i = 0
    for x in range(len(testSet)):
        i += 1
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        print('t-' + str(i) +'> predicted=' + repr(result) + ', actual=' + repr(testSet[x][0]))
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')


main()
# Out:
# Train set: 416
# Test set: 208
# t-1> predicted='B', actual='R'
# t-2> predicted='R', actual='R'
# t-3> predicted='R', actual='R'
# t-4> predicted='R', actual='R'
# t-5> predicted='R', actual='R'
# t-6> predicted='R', actual='R'
# t-7> predicted='R', actual='R'
# t-8> predicted='R', actual='B'
# t-9> predicted='R', actual='R'
# t-10> predicted='R', actual='R'
# t-11> predicted='R', actual='R'
# t-12> predicted='R', actual='R'
# t-13> predicted='R', actual='R'
# t-14> predicted='R', actual='R'
# t-15> predicted='R', actual='R'
# t-16> predicted='R', actual='R'
# t-17> predicted='R', actual='R'
# t-18> predicted='R', actual='R'
# t-19> predicted='R', actual='R'
# t-20> predicted='R', actual='R'
# t-21> predicted='R', actual='R'
# t-22> predicted='R', actual='R'
# t-23> predicted='L', actual='L'
# t-24> predicted='L', actual='L'
# t-25> predicted='L', actual='L'
# t-26> predicted='L', actual='B'
# t-27> predicted='R', actual='R'
# t-28> predicted='R', actual='R'
# t-29> predicted='R', actual='R'
# t-30> predicted='R', actual='R'
# t-31> predicted='L', actual='L'
# t-32> predicted='R', actual='R'
# t-33> predicted='R', actual='R'
# t-34> predicted='L', actual='L'
# t-35> predicted='B', actual='L'
# t-36> predicted='R', actual='R'
# t-37> predicted='R', actual='R'
# t-38> predicted='R', actual='R'
# t-39> predicted='R', actual='R'
# t-40> predicted='R', actual='R'
# t-41> predicted='R', actual='R'
# t-42> predicted='R', actual='R'
# t-43> predicted='R', actual='R'
# t-44> predicted='R', actual='R'
# t-45> predicted='R', actual='R'
# t-46> predicted='R', actual='R'
# t-47> predicted='R', actual='R'
# t-48> predicted='R', actual='R'
# t-49> predicted='R', actual='R'
# t-50> predicted='B', actual='L'
# t-51> predicted='R', actual='L'
# t-52> predicted='R', actual='B'
# t-53> predicted='R', actual='R'
# t-54> predicted='R', actual='R'
# t-55> predicted='R', actual='R'
# t-56> predicted='R', actual='R'
# t-57> predicted='R', actual='R'
# t-58> predicted='R', actual='L'
# t-59> predicted='R', actual='B'
# t-60> predicted='R', actual='R'
# t-61> predicted='R', actual='R'
# t-62> predicted='R', actual='R'
# t-63> predicted='R', actual='R'
# t-64> predicted='R', actual='R'
# t-65> predicted='R', actual='R'
# t-66> predicted='L', actual='L'
# t-67> predicted='L', actual='L'
# t-68> predicted='R', actual='B'
# t-69> predicted='R', actual='R'
# t-70> predicted='L', actual='L'
# t-71> predicted='L', actual='L'
# t-72> predicted='R', actual='R'
# t-73> predicted='L', actual='L'
# t-74> predicted='R', actual='B'
# t-75> predicted='R', actual='L'
# t-76> predicted='R', actual='R'
# t-77> predicted='L', actual='L'
# t-78> predicted='L', actual='L'
# t-79> predicted='L', actual='L'
# t-80> predicted='L', actual='L'
# t-81> predicted='R', actual='R'
# t-82> predicted='L', actual='L'
# t-83> predicted='R', actual='R'
# t-84> predicted='R', actual='R'
# t-85> predicted='R', actual='R'
# t-86> predicted='L', actual='L'
# t-87> predicted='L', actual='B'
# t-88> predicted='R', actual='R'
# t-89> predicted='R', actual='R'
# t-90> predicted='L', actual='B'
# t-91> predicted='R', actual='R'
# t-92> predicted='R', actual='R'
# t-93> predicted='R', actual='R'
# t-94> predicted='R', actual='R'
# t-95> predicted='R', actual='R'
# t-96> predicted='R', actual='L'
# t-97> predicted='L', actual='L'
# t-98> predicted='L', actual='B'
# t-99> predicted='R', actual='R'
# t-100> predicted='L', actual='L'
# t-101> predicted='R', actual='R'
# t-102> predicted='R', actual='R'
# t-103> predicted='R', actual='R'
# t-104> predicted='L', actual='L'
# t-105> predicted='L', actual='L'
# t-106> predicted='R', actual='B'
# t-107> predicted='R', actual='R'
# t-108> predicted='R', actual='R'
# t-109> predicted='L', actual='L'
# t-110> predicted='R', actual='R'
# t-111> predicted='R', actual='R'
# t-112> predicted='L', actual='L'
# t-113> predicted='L', actual='L'
# t-114> predicted='L', actual='L'
# t-115> predicted='R', actual='R'
# t-116> predicted='R', actual='R'
# t-117> predicted='R', actual='R'
# t-118> predicted='L', actual='L'
# t-119> predicted='L', actual='L'
# t-120> predicted='L', actual='L'
# t-121> predicted='L', actual='L'
# t-122> predicted='L', actual='L'
# t-123> predicted='L', actual='L'
# t-124> predicted='R', actual='B'
# t-125> predicted='L', actual='L'
# t-126> predicted='L', actual='L'
# t-127> predicted='R', actual='R'
# t-128> predicted='R', actual='R'
# t-129> predicted='L', actual='L'
# t-130> predicted='L', actual='L'
# t-131> predicted='R', actual='R'
# t-132> predicted='R', actual='R'
# t-133> predicted='R', actual='R'
# t-134> predicted='L', actual='L'
# t-135> predicted='R', actual='R'
# t-136> predicted='R', actual='R'
# t-137> predicted='R', actual='R'
# t-138> predicted='R', actual='R'
# t-139> predicted='R', actual='R'
# t-140> predicted='R', actual='R'
# t-141> predicted='L', actual='L'
# t-142> predicted='L', actual='L'
# t-143> predicted='L', actual='L'
# t-144> predicted='R', actual='R'
# t-145> predicted='L', actual='R'
# t-146> predicted='R', actual='R'
# t-147> predicted='R', actual='R'
# t-148> predicted='L', actual='L'
# t-149> predicted='L', actual='L'
# t-150> predicted='L', actual='L'
# t-151> predicted='R', actual='B'
# t-152> predicted='L', actual='L'
# t-153> predicted='L', actual='L'
# t-154> predicted='L', actual='L'
# t-155> predicted='R', actual='L'
# t-156> predicted='L', actual='L'
# t-157> predicted='R', actual='B'
# t-158> predicted='L', actual='L'
# t-159> predicted='R', actual='L'
# t-160> predicted='R', actual='R'
# t-161> predicted='L', actual='L'
# t-162> predicted='L', actual='L'
# t-163> predicted='L', actual='L'
# t-164> predicted='L', actual='L'
# t-165> predicted='L', actual='L'
# t-166> predicted='L', actual='L'
# t-167> predicted='L', actual='B'
# t-168> predicted='R', actual='R'
# t-169> predicted='L', actual='L'
# t-170> predicted='L', actual='L'
# t-171> predicted='R', actual='R'
# t-172> predicted='R', actual='R'
# t-173> predicted='R', actual='R'
# t-174> predicted='L', actual='L'
# t-175> predicted='L', actual='L'
# t-176> predicted='L', actual='L'
# t-177> predicted='L', actual='R'
# t-178> predicted='R', actual='R'
# t-179> predicted='L', actual='L'
# t-180> predicted='R', actual='R'
# t-181> predicted='R', actual='R'
# t-182> predicted='L', actual='L'
# t-183> predicted='L', actual='L'
# t-184> predicted='L', actual='L'
# t-185> predicted='L', actual='L'
# t-186> predicted='L', actual='L'
# t-187> predicted='L', actual='L'
# t-188> predicted='L', actual='L'
# t-189> predicted='L', actual='L'
# t-190> predicted='L', actual='L'
# t-191> predicted='R', actual='L'
# t-192> predicted='R', actual='R'
# t-193> predicted='L', actual='L'
# t-194> predicted='L', actual='L'
# t-195> predicted='L', actual='L'
# t-196> predicted='L', actual='L'
# t-197> predicted='L', actual='L'
# t-198> predicted='L', actual='L'
# t-199> predicted='L', actual='L'
# t-200> predicted='L', actual='L'
# t-201> predicted='L', actual='L'
# t-202> predicted='R', actual='B'
# t-203> predicted='R', actual='B'
# t-204> predicted='L', actual='L'
# t-205> predicted='L', actual='L'
# t-206> predicted='L', actual='L'
# t-207> predicted='L', actual='L'
# t-208> predicted='L', actual='L'
# Accuracy: 86.53846153846155%

# %%
# Example of kNN implemented from Scratch in Python

import csv
import random
import math
import operator

def loadDataset(filename, split, trainingSet=[], testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset) - 1):
            for y in range(1, 5):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])


def euclideanDistance(instance1, instance2):
    distance = 0
    for x in range(1, 5):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)


def getNeighbors(trainingSet, testInstance, k):
    distances = []
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x])
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors


def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][0]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]

def getAccuracy(testSet, predictions):
    correct = 0

    for x in range(len(testSet)):
        if testSet[x][0] == predictions[x]:
            correct += 1
    return (correct / float(len(testSet))) * 100.0


def main():
    # prepare data
    trainingSet = []
    testSet = []
    split = 0.67
    loadDataset('balance-scale.data', split, trainingSet, testSet)
    print('Train set: ' + repr(len(trainingSet)))
    print('Test set: ' + repr(len(testSet)))
    # generate predictions
    predictions = []
    k = 7
    i = 0
    for x in range(len(testSet)):
        i += 1
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        print('t-' + str(i) +'> predicted=' + repr(result) + ', actual=' + repr(testSet[x][0]))
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')


main()
# Out:
# Train set: 408
# Test set: 216
# t-1> predicted='B', actual='B'
# t-2> predicted='R', actual='R'
# t-3> predicted='R', actual='R'
# t-4> predicted='R', actual='R'
# t-5> predicted='R', actual='R'
# t-6> predicted='R', actual='R'
# t-7> predicted='R', actual='R'
# t-8> predicted='R', actual='R'
# t-9> predicted='R', actual='R'
# t-10> predicted='L', actual='L'
# t-11> predicted='R', actual='R'
# t-12> predicted='R', actual='R'
# t-13> predicted='R', actual='R'
# t-14> predicted='R', actual='R'
# t-15> predicted='R', actual='R'
# t-16> predicted='R', actual='R'
# t-17> predicted='R', actual='R'
# t-18> predicted='R', actual='R'
# t-19> predicted='R', actual='R'
# t-20> predicted='R', actual='R'
# t-21> predicted='R', actual='R'
# t-22> predicted='R', actual='R'
# t-23> predicted='R', actual='R'
# t-24> predicted='R', actual='R'
# t-25> predicted='R', actual='R'
# t-26> predicted='R', actual='R'
# t-27> predicted='R', actual='R'
# t-28> predicted='R', actual='R'
# t-29> predicted='R', actual='R'
# t-30> predicted='R', actual='R'
# t-31> predicted='R', actual='R'
# t-32> predicted='L', actual='L'
# t-33> predicted='L', actual='B'
# t-34> predicted='R', actual='R'
# t-35> predicted='R', actual='R'
# t-36> predicted='R', actual='R'
# t-37> predicted='R', actual='R'
# t-38> predicted='R', actual='R'
# t-39> predicted='L', actual='L'
# t-40> predicted='L', actual='L'
# t-41> predicted='R', actual='B'
# t-42> predicted='L', actual='L'
# t-43> predicted='L', actual='R'
# t-44> predicted='R', actual='R'
# t-45> predicted='R', actual='R'
# t-46> predicted='R', actual='R'
# t-47> predicted='R', actual='R'
# t-48> predicted='L', actual='L'
# t-49> predicted='R', actual='R'
# t-50> predicted='R', actual='R'
# t-51> predicted='R', actual='R'
# t-52> predicted='R', actual='R'
# t-53> predicted='R', actual='R'
# t-54> predicted='R', actual='R'
# t-55> predicted='R', actual='R'
# t-56> predicted='L', actual='L'
# t-57> predicted='R', actual='R'
# t-58> predicted='R', actual='R'
# t-59> predicted='R', actual='R'
# t-60> predicted='R', actual='R'
# t-61> predicted='R', actual='R'
# t-62> predicted='R', actual='R'
# t-63> predicted='R', actual='R'
# t-64> predicted='R', actual='R'
# t-65> predicted='R', actual='R'
# t-66> predicted='B', actual='L'
# t-67> predicted='R', actual='L'
# t-68> predicted='R', actual='B'
# t-69> predicted='R', actual='R'
# t-70> predicted='R', actual='R'
# t-71> predicted='B', actual='R'
# t-72> predicted='R', actual='B'
# t-73> predicted='R', actual='R'
# t-74> predicted='R', actual='R'
# t-75> predicted='R', actual='R'
# t-76> predicted='L', actual='L'
# t-77> predicted='L', actual='L'
# t-78> predicted='R', actual='L'
# t-79> predicted='R', actual='R'
# t-80> predicted='R', actual='R'
# t-81> predicted='R', actual='R'
# t-82> predicted='R', actual='R'
# t-83> predicted='L', actual='L'
# t-84> predicted='L', actual='L'
# t-85> predicted='L', actual='L'
# t-86> predicted='L', actual='L'
# t-87> predicted='R', actual='L'
# t-88> predicted='R', actual='R'
# t-89> predicted='R', actual='R'
# t-90> predicted='L', actual='L'
# t-91> predicted='R', actual='B'
# t-92> predicted='L', actual='L'
# t-93> predicted='R', actual='R'
# t-94> predicted='L', actual='L'
# t-95> predicted='L', actual='L'
# t-96> predicted='L', actual='L'
# t-97> predicted='L', actual='L'
# t-98> predicted='L', actual='R'
# t-99> predicted='R', actual='L'
# t-100> predicted='R', actual='R'
# t-101> predicted='R', actual='R'
# t-102> predicted='R', actual='R'
# t-103> predicted='R', actual='R'
# t-104> predicted='R', actual='R'
# t-105> predicted='R', actual='R'
# t-106> predicted='R', actual='R'
# t-107> predicted='R', actual='R'
# t-108> predicted='R', actual='R'
# t-109> predicted='L', actual='L'
# t-110> predicted='L', actual='L'
# t-111> predicted='L', actual='L'
# t-112> predicted='L', actual='L'
# t-113> predicted='R', actual='B'
# t-114> predicted='R', actual='R'
# t-115> predicted='R', actual='R'
# t-116> predicted='R', actual='R'
# t-117> predicted='R', actual='R'
# t-118> predicted='R', actual='R'
# t-119> predicted='L', actual='L'
# t-120> predicted='L', actual='L'
# t-121> predicted='L', actual='R'
# t-122> predicted='L', actual='L'
# t-123> predicted='L', actual='L'
# t-124> predicted='R', actual='R'
# t-125> predicted='L', actual='L'
# t-126> predicted='R', actual='R'
# t-127> predicted='L', actual='L'
# t-128> predicted='L', actual='L'
# t-129> predicted='L', actual='L'
# t-130> predicted='L', actual='L'
# t-131> predicted='R', actual='R'
# t-132> predicted='L', actual='L'
# t-133> predicted='L', actual='L'
# t-134> predicted='L', actual='L'
# t-135> predicted='L', actual='L'
# t-136> predicted='L', actual='L'
# t-137> predicted='R', actual='R'
# t-138> predicted='L', actual='L'
# t-139> predicted='R', actual='B'
# t-140> predicted='R', actual='R'
# t-141> predicted='L', actual='L'
# t-142> predicted='L', actual='L'
# t-143> predicted='R', actual='L'
# t-144> predicted='R', actual='R'
# t-145> predicted='R', actual='R'
# t-146> predicted='L', actual='L'
# t-147> predicted='L', actual='L'
# t-148> predicted='L', actual='L'
# t-149> predicted='L', actual='L'
# t-150> predicted='L', actual='L'
# t-151> predicted='R', actual='B'
# t-152> predicted='R', actual='R'
# t-153> predicted='L', actual='L'
# t-154> predicted='L', actual='L'
# t-155> predicted='R', actual='R'
# t-156> predicted='R', actual='R'
# t-157> predicted='R', actual='R'
# t-158> predicted='L', actual='L'
# t-159> predicted='R', actual='R'
# t-160> predicted='L', actual='L'
# t-161> predicted='L', actual='L'
# t-162> predicted='L', actual='L'
# t-163> predicted='L', actual='L'
# t-164> predicted='L', actual='L'
# t-165> predicted='L', actual='L'
# t-166> predicted='L', actual='L'
# t-167> predicted='R', actual='R'
# t-168> predicted='L', actual='B'
# t-169> predicted='R', actual='R'
# t-170> predicted='R', actual='R'
# t-171> predicted='R', actual='R'
# t-172> predicted='L', actual='L'
# t-173> predicted='L', actual='L'
# t-174> predicted='L', actual='L'
# t-175> predicted='L', actual='L'
# t-176> predicted='R', actual='R'
# t-177> predicted='L', actual='L'
# t-178> predicted='L', actual='L'
# t-179> predicted='L', actual='L'
# t-180> predicted='L', actual='L'
# t-181> predicted='B', actual='L'
# t-182> predicted='L', actual='L'
# t-183> predicted='L', actual='L'
# t-184> predicted='R', actual='R'
# t-185> predicted='R', actual='L'
# t-186> predicted='R', actual='R'
# t-187> predicted='R', actual='R'
# t-188> predicted='R', actual='R'
# t-189> predicted='R', actual='R'
# t-190> predicted='L', actual='L'
# t-191> predicted='L', actual='L'
# t-192> predicted='R', actual='B'
# t-193> predicted='L', actual='L'
# t-194> predicted='R', actual='L'
# t-195> predicted='R', actual='R'
# t-196> predicted='L', actual='L'
# t-197> predicted='R', actual='R'
# t-198> predicted='L', actual='L'
# t-199> predicted='L', actual='L'
# t-200> predicted='R', actual='R'
# t-201> predicted='R', actual='B'
# t-202> predicted='L', actual='L'
# t-203> predicted='L', actual='L'
# t-204> predicted='L', actual='L'
# t-205> predicted='L', actual='L'
# t-206> predicted='B', actual='L'
# t-207> predicted='L', actual='L'
# t-208> predicted='L', actual='L'
# t-209> predicted='L', actual='L'
# t-210> predicted='L', actual='L'
# t-211> predicted='L', actual='L'
# t-212> predicted='L', actual='L'
# t-213> predicted='L', actual='L'
# t-214> predicted='L', actual='L'
# t-215> predicted='L', actual='L'
# t-216> predicted='L', actual='L'
# Accuracy: 88.42592592592592%
