# %%
# Example of kNN implemented from Scratch in Python

import csv
import random
import math
import operator

def loadDataset(filename, split, trainingSet=[], testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset) - 1):
            for y in range(4):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])


def euclideanDistance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)


def getNeighbors(trainingSet, testInstance, k):
    distances = []
    length = len(testInstance) - 1
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x], length)
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors


def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][-1]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]


def getAccuracy(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if testSet[x][-1] == predictions[x]:
            correct += 1
    return (correct / float(len(testSet))) * 100.0


def main():
    # prepare data
    trainingSet = []
    testSet = []
    split = 0.67
    loadDataset('iris.data', split, trainingSet, testSet)
    print('Train set: ' + repr(len(trainingSet)))
    print('Test set: ' + repr(len(testSet)))
    # generate predictions
    predictions = []
    k = 3
    i = 0
    for x in range(len(testSet)):
        i+=1
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        print('t-' + str(i) + '> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')


main()
# Out:
# Train set: 106
# Test set: 44
# t-1> predicted='Iris-setosa', actual='Iris-setosa'
# t-2> predicted='Iris-setosa', actual='Iris-setosa'
# t-3> predicted='Iris-setosa', actual='Iris-setosa'
# t-4> predicted='Iris-setosa', actual='Iris-setosa'
# t-5> predicted='Iris-setosa', actual='Iris-setosa'
# t-6> predicted='Iris-setosa', actual='Iris-setosa'
# t-7> predicted='Iris-setosa', actual='Iris-setosa'
# t-8> predicted='Iris-setosa', actual='Iris-setosa'
# t-9> predicted='Iris-setosa', actual='Iris-setosa'
# t-10> predicted='Iris-setosa', actual='Iris-setosa'
# t-11> predicted='Iris-setosa', actual='Iris-setosa'
# t-12> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-13> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-14> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-15> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-16> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-17> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-18> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-19> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-20> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-21> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-22> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-23> predicted='Iris-versicolor', actual='Iris-versicolor'
# t-24> predicted='Iris-virginica', actual='Iris-virginica'
# t-25> predicted='Iris-virginica', actual='Iris-virginica'
# t-26> predicted='Iris-virginica', actual='Iris-virginica'
# t-27> predicted='Iris-virginica', actual='Iris-virginica'
# t-28> predicted='Iris-virginica', actual='Iris-virginica'
# t-29> predicted='Iris-virginica', actual='Iris-virginica'
# t-30> predicted='Iris-virginica', actual='Iris-virginica'
# t-31> predicted='Iris-virginica', actual='Iris-virginica'
# t-32> predicted='Iris-virginica', actual='Iris-virginica'
# t-33> predicted='Iris-virginica', actual='Iris-virginica'
# t-34> predicted='Iris-virginica', actual='Iris-virginica'
# t-35> predicted='Iris-virginica', actual='Iris-virginica'
# t-36> predicted='Iris-virginica', actual='Iris-virginica'
# t-37> predicted='Iris-virginica', actual='Iris-virginica'
# t-38> predicted='Iris-virginica', actual='Iris-virginica'
# t-39> predicted='Iris-virginica', actual='Iris-virginica'
# t-40> predicted='Iris-virginica', actual='Iris-virginica'
# t-41> predicted='Iris-virginica', actual='Iris-virginica'
# t-42> predicted='Iris-virginica', actual='Iris-virginica'
# t-43> predicted='Iris-versicolor', actual='Iris-virginica'
# t-44> predicted='Iris-virginica', actual='Iris-virginica'
# Accuracy: 97.72727272727273%

# %%
# Example of kNN implemented from Scratch in Python

import csv
import random
import math
import operator

def loadDataset(filename, split, trainingSet=[], testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset) - 1):
            for y in range(4):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])


def euclideanDistance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)

def manhattanDistance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += abs(instance1[x] - instance2[x])
    return distance

def getNeighbors(trainingSet, testInstance, k):
    distances = []
    length = len(testInstance) - 1

    for x in range(len(trainingSet)):
        # dist = euclideanDistance(testInstance, trainingSet[x], length)
        dist = manhattanDistance(testInstance, trainingSet[x], length)
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors


def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][-1]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]


def getAccuracy(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if testSet[x][-1] == predictions[x]:
            correct += 1
    return (correct / float(len(testSet))) * 100.0


def main():
    # prepare data
    trainingSet = []
    testSet = []
    split = 0.67
    loadDataset('iris.data', split, trainingSet, testSet)
    print('Train set: ' + repr(len(trainingSet)))
    print('Test set: ' + repr(len(testSet)))
    # generate predictions
    predictions = []
    k = 3
    for x in range(len(testSet)):
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        print('> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')


main()
# Out:
# Train set: 101
# Test set: 49
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-setosa', actual='Iris-setosa'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-versicolor', actual='Iris-versicolor'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# > predicted='Iris-virginica', actual='Iris-virginica'
# Accuracy: 97.95918367346938%
